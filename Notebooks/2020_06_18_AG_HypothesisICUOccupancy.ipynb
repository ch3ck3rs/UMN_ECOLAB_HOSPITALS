# %% [markdown]
# ## ECL-UMN Collaboration  Kaggle COVID19 Data (Non-Complete ICU Capacity Group)
# Albert Goldfain (albert.goldfain@ecolab.com)
#
# ### Hypothesis:
# Counties with older populations and fewer ICU beds will have higher COVID-19 death counts.
#
# ### Data:
# * NYT county level case/death (UNCOVER)
# * ICU data (Kaggle Kernel)
# * ICU supplemental data (UNCOVER)
#
# ### Environment:
# * Download full [UNCOVER](https://www.kaggle.com/roche-data-science-coalition/uncover/download) data set into ``uncover/`` directory.
# * Kaggle kernel dataset in ``kaggle/`` directory.
# * Current notebook in ``notebooks/`` directory.

# %%
#imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Data Preparation

# %%
#Read in CSVs
kaggle_icu_df = pd.read_csv('../Data/Kaggle/data-FPBfZ.csv')
definitive_hosp = pd.read_csv('../Data/Uncover/esri_covid-19/esri_covid-19/definitive-healthcare-usa-hospital-beds.csv')
nyt = pd.read_csv('../Data/Uncover/New_York_Times/covid-19-county-level-data.csv')

# %%
nyt.tail(5)
# Out:
#               date      county    state     fips  cases  deaths
# 245854  2020-06-17  Sweetwater  Wyoming  56037.0     43       0
# 245855  2020-06-17       Teton  Wyoming  56039.0    107       1
# 245856  2020-06-17       Uinta  Wyoming  56041.0    104       0
# 245857  2020-06-17    Washakie  Wyoming  56043.0     38       3
# 245858  2020-06-17      Weston  Wyoming  56045.0      1       0

# %% [markdown]
# In order to establish how far along each county is relative to the first wave, extract and save the date of first infection for each county. This might be used as a baseline to compare counties position on the COVID case curve, but will be problematic as a long term variable.

# %%
#the NYT data are cumulative, store off the latest cases in a separate variable (note, this changes with each data pull)
latest_cases = nyt[nyt.date=="2020-06-17"]

# %%
first_case_dict = {}
for row in nyt.sort_values(by="date",ascending=False).iterrows():
    #key-value into dict will be (county,state) tuple
    current_tuple = (row[1]["county"],row[1]["state"])
    first_case_dict[current_tuple] = row[1]['date']

# %%
#write out first-case output
pd.DataFrame([[c,s,first_case_dict[(c,s)]] for (c,s) in first_case_dict.keys()],
            columns=['county','state','first_case_date']).to_csv('../Generated_Files/first_case_by_county.csv',index=False)

# %%
#enrich latest NYT data with days since first case
days_since_first_case = []
for row in latest_cases.iterrows():
    first_case = first_case_dict[(row[1]["county"],row[1]["state"])]
    days_since_first_case.append((pd.to_datetime(row[1]["date"]) - pd.to_datetime(first_case)).days)

latest_cases.loc[:,'days_since_first_case'] = days_since_first_case
# Out:
# C:\Users\goldfal\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\goldfal\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
#sum county bed data in definitive dataset
definitive_icu = []
for row in definitive_hosp[['county_nam','state_name','num_licens','num_staffe', 'num_icu_be', 'bed_utiliz', 'potential']].iterrows():
    if(row[1]['num_icu_be']>0):
        definitive_icu.append(row[1])
definitive_icu_df = pd.DataFrame(definitive_icu).groupby(['state_name','county_nam']).sum().reset_index(0)    
definitive_icu_df.loc[:,"county_name"] = definitive_icu_df.index
definitive_icu_df.index = range(len(definitive_icu_df))

# %%
#merge with kaggle ICU kernel data
icu_beds = pd.merge(definitive_icu_df,kaggle_icu_df,left_on=['county_name','state_name'],right_on=['County','State'])

# %%
icu_beds = icu_beds.rename(columns={'Population Aged 60+':'popOver60',
                                    'Percent of Population Aged 60+':'percentOver60',
                                    'Residents Aged 60+ Per Each ICU Bed':'popOver60perICU'})
icu_beds.columns
# Out:
# Index(['state_name', 'num_icu_be', 'bed_utiliz', 'potential', 'county_name',
#        'State', 'County', 'ICU Beds', 'Total Population', 'popOver60',
#        'percentOver60', 'popOver60perICU'],
#       dtype='object')

# %% [markdown]
# Now we compute proportion of over-60 yo residents to ICU beds for each county (aka pco60) and pull out a few important features as a county level ICU summary before merging with NYT case count data.

# %%
icu_beds.loc[:,'pco60']= icu_beds['popOver60perICU'] / icu_beds['Total Population']
icu_summary = icu_beds[['State','County','Total Population','num_icu_be', 'bed_utiliz', 'potential',
                        'pco60','popOver60','percentOver60','popOver60perICU']]
icu_merged = pd.merge(icu_summary,latest_cases,left_on=["County","State"],right_on=["county","state"])
sns.distplot(icu_beds.pco60.dropna()).set_title('Distribution of pco60 feature')
# Out:
# Text(0.5,1,'Distribution of pco60 feature')

# %%
#derive some per capita stats
icu_merged.loc[:,'deaths_per_capita']= icu_merged['deaths'] / icu_merged['Total Population']
icu_merged.loc[:,'cases_per_capita']= icu_merged['cases'] / icu_merged['Total Population']
icu_merged.loc[:,'deaths_per_case'] = icu_merged['deaths'] / icu_merged['cases']

# %%
#save file
icu_merged[icu_merged['Total Population']>0].dropna().to_csv('../Generated_Files/nyt_enriched.csv',index=False)

# %% [markdown]
# ### Data Exploration

# %%
#sample counties with at least one death
sample = icu_merged[icu_merged.deaths_per_capita>0]
sample.describe()
# Out:
#        Total Population   num_icu_be   bed_utiliz    potential        pco60  \
# count      1.139000e+03  1139.000000  1139.000000  1139.000000  1123.000000
# mean       2.308859e+05    50.562774     1.160497    82.145742     0.020566
# std        5.016469e+05   110.865164     2.108612   201.488834     0.023819
# min        1.023900e+04     1.000000     0.060959  -444.000000     0.000084
# 25%        4.451100e+04     8.000000     0.368689     0.000000     0.003829
# 50%        9.144200e+04    17.000000     0.579493    27.000000     0.012243
# 75%        2.123830e+05    47.000000     1.190126    80.000000     0.029684
# max        1.010572e+07  2004.000000    44.525842  2822.000000     0.241792
#
#           popOver60  percentOver60  popOver60perICU          fips  \
# count  1.139000e+03    1139.000000      1123.000000   1139.000000
# mean   4.710878e+04      22.570149      1310.713268  28994.064969
# std    9.279692e+04       4.844638       925.229997  15167.617962
# min    2.329000e+03      10.300000       137.000000   1001.000000
# 25%    1.034900e+04      19.450000       706.500000  17178.000000
# 50%    2.009900e+04      22.300000      1081.000000  28075.000000
# 75%    4.581400e+04      24.900000      1639.500000  42006.000000
# max    1.800341e+06      64.200000      8469.000000  56039.000000
#
#               cases       deaths  days_since_first_case  deaths_per_capita  \
# count   1139.000000  1139.000000            1139.000000        1139.000000
# mean    1523.606673    77.427568              89.882353           0.000234
# std     4852.021798   270.117589               9.234222           0.000316
# min        5.000000     1.000000              47.000000           0.000004
# 25%      108.500000     3.000000              84.000000           0.000044
# 50%      332.000000    10.000000              89.000000           0.000106
# 75%      969.000000    40.000000              95.000000           0.000296
# max    85858.000000  4304.000000             148.000000           0.002193
#
#        cases_per_capita  deaths_per_case
# count       1139.000000      1139.000000
# mean           0.005323         0.046810
# std            0.006072         0.038314
# min            0.000145         0.000920
# 25%            0.001719         0.018679
# 50%            0.003429         0.036122
# 75%            0.006398         0.066064
# max            0.054735         0.285714

# %%
sns.pairplot(sample[['num_icu_be',
                     #'bed_utiliz',
                     #'potential',
                     'cases_per_capita',
                     'deaths_per_capita',
                     'deaths_per_case',
                     'pco60',
                     'popOver60',
                     'percentOver60',
                     'popOver60perICU']].dropna())

# %%
sns.regplot('pco60','deaths_per_capita',data=sample).set_title("County per capita 60+ per ICU bed vs per capita deaths\n NYT enriched data as of April 27")
# Out:
# Text(0.5,1,'County per capita 60+ per ICU bed vs per capita deaths\n NYT enriched data as of April 27')

# %%
sns.regplot('popOver60','deaths_per_capita',data=sample).set_title("County raw pop 60+ vs per capita deaths\n NYT enriched data as of April 27")
# Out:
# Text(0.5,1,'County raw pop 60+ vs per capita deaths\n NYT enriched data as of April 27')

# %% [markdown]
# One explanation for the smaller pco60 for higher deaths per capita is that we aren't far enough into the curve.

# %%
f,(ax1,ax2) = plt.subplots(1,2,sharey=False,figsize=(15,4))

sns.lineplot(sample['days_since_first_case'],sample['deaths_per_capita'],ax=ax1)
sns.lineplot(sample['days_since_first_case'],sample['pco60'],ax=ax2)

# %%
f,(ax1,ax2) = plt.subplots(1,2,sharey=False,figsize=(15,4))

sns.lineplot(sample['days_since_first_case'],sample['deaths_per_capita'],ax=ax1)
sns.lineplot(sample['days_since_first_case'],sample['num_icu_be'],ax=ax2)

# %%
f,(ax1,ax2) = plt.subplots(1,2,sharey=False,figsize=(15,4))

sns.lineplot(sample['days_since_first_case'],sample['deaths_per_capita'],ax=ax1)
sns.lineplot(sample['days_since_first_case'],sample['popOver60'],ax=ax2)

# %% [markdown]
# The highest pco60 counties are 20-60 days since first case, but the highest death per capita occurs in counties closer to 110 and 140 days in

# %%
sample[sample['days_since_first_case']>80].sort_values(by='deaths_per_capita',ascending=False)
# Out:
#               State           County  Total Population  num_icu_be  \
# 766      New Jersey            Essex            800401       215.0
# 792      New Mexico         McKinley             72849         5.0
# 779      New Jersey            Union            557320        55.0
# 775      New Jersey          Passaic            510563        53.0
# 818        New York           Nassau           1363069       235.0
# 768      New Jersey           Hudson            679756        89.0
# 761      New Jersey           Bergen            937920       112.0
# 41          Alabama       Tallapoosa             40756         6.0
# 236         Georgia        Dougherty             91522        50.0
# 269         Georgia            Upson             26241        28.0
# 152        Colorado           Morgan             28123         6.0
# 836        New York      Westchester            975321       158.0
# 673     Mississippi          Leflore             30113         9.0
# 624        Michigan            Wayne           1763822       411.0
# 159     Connecticut         Hartford            897417       216.0
# 158     Connecticut        Fairfield            947328       157.0
# 774      New Jersey            Ocean            589699        94.0
# 770      New Jersey           Mercer            373362        80.0
# 569   Massachusetts          Hampden            469188        83.0
# 567   Massachusetts            Essex            775860        98.0
# 517       Louisiana          Orleans            388182        62.0
# 831        New York          Suffolk           1497595       250.0
# 777      New Jersey         Somerset            333316        28.0
# 780      New Jersey           Warren            107088        20.0
# 771      New Jersey        Middlesex            837288        97.0
# 572   Massachusetts          Norfolk            694389        59.0
# 773      New Jersey           Morris            498847        81.0
# 4           Alabama           Butler             20126         7.0
# 573   Massachusetts         Plymouth            509114        47.0
# 574   Massachusetts          Suffolk            780685       453.0
# ...             ...              ...               ...         ...
# 1385        Wyoming          Natrona             81023        14.0
# 11          Alabama          Cullman             81703        12.0
# 1248           Utah            Davis            334977        22.0
# 279           Idaho          Bannock             84113        20.0
# 1004         Oregon        Josephine             84514        12.0
# 947            Ohio        Muskingum             85933        24.0
# 689        Missouri            Boone            174589       114.0
# 1143      Tennessee            Maury             87606        41.0
# 476        Kentucky          Madison             88376        12.0
# 755   New Hampshire          Grafton             89280        52.0
# 1223          Texas           Nueces            358484       105.0
# 275          Hawaii         Honolulu            990060       136.0
# 1138      Tennessee             Knox            452286       147.0
# 121      California       Santa Cruz            273263        22.0
# 835        New York            Wayne             91442         8.0
# 66         Arkansas          Garland             97994        41.0
# 107      California           Nevada             98838        10.0
# 725         Montana         Gallatin            100733         8.0
# 282           Idaho       Bonneville            110404        35.0
# 728         Montana         Missoula            114231        32.0
# 1233          Texas        Tom Green            116906        29.0
# 1246           Utah            Cache            120288        14.0
# 1005         Oregon             Lane            363471        71.0
# 1022   Pennsylvania            Blair            124736        42.0
# 125      California           Sonoma            500943        82.0
# 1225          Texas           Parker            125963        20.0
# 1306     Washington           Kitsap            258903        20.0
# 1359      Wisconsin         Marathon            135293        52.0
# 88       California            Butte            225207        43.0
# 117      California  San Luis Obispo            280119        54.0
#
#       bed_utiliz  potential     pco60  popOver60  percentOver60  \
# 766     4.537763       1066  0.000687     146732           18.3
# 792     0.675636         42  0.032739      11923           16.4
# 779     1.161934        258  0.002383     106249           19.1
# 775     1.302724        124  0.001984      98279           19.2
# 818     6.128906       1076  0.000506     318040           23.3
# 768     3.059482        675  0.001540     109974           16.2
# 761     3.885920        940  0.001535     211672           22.6
# 41      0.460461         47  0.045000      11006           27.0
# 236     0.599089        282  0.004152      18997           20.8
# 269     0.372288         28  0.008574       6294           24.0
# 152     0.145662         14  0.035843       6047           21.5
# 836     5.330599        460  0.001228     214443           22.0
# 673     0.297949         35  0.020921       5674           18.8
# 624     8.494207        904  0.000351     362535           20.6
# 159     3.682334        138  0.001039     201242           22.4
# 158     3.713354          0  0.001204     197334           20.8
# 774     2.250067        209  0.002678     167321           28.4
# 770     2.815807        379  0.002191      75299           20.2
# 569     2.702126         96  0.001854     103567           22.1
# 567     2.837629         22  0.002281     173485           22.4
# 517     1.372358        282  0.001731      74618           19.2
# 831     7.998760        434  0.000775     326104           21.8
# 777     0.571394         80  0.007254      67698           20.3
# 780     1.081502        153  0.011477      24579           23.0
# 771     2.619149        355  0.001063     164627           19.7
# 572     2.415465         30  0.003788     155147           22.3
# 773     1.839061        178  0.002436     110520           22.2
# 4       0.183251         28  0.036570       5151           25.6
# 573     2.079831         41  0.005011     119899           23.6
# 574     5.752342        341  0.000360     125537           16.1
# ...          ...        ...       ...        ...            ...
# 1385    0.461851          0  0.014132      16036           19.8
# 11      0.508172          0  0.020060      19667           24.1
# 1248    0.644330         97  0.006191      45623           13.6
# 279     0.585182         68  0.009368      15750           18.7
# 1004    0.556164          4  0.027948      28339           33.5
# 947     0.499330         39  0.004876      20112           23.4
# 689     1.169685         57  0.001478      28350           16.2
# 1143    0.535617        -10  0.003299      18777           21.4
# 476     0.914484         45  0.015230      16155           18.3
# 755     1.342375         -5  0.004928      23734           26.6
# 1223    1.856000        127  0.001660      68411           19.1
# 275     4.703285         24  0.001490     218287           22.0
# 1138    2.823844        146  0.000816      93686           20.7
# 121     0.996805         20  0.009518      57232           20.9
# 835     0.499471         19  0.030336      22194           24.3
# 66      1.223977         90  0.007153      28731           29.3
# 107     1.072000         10  0.034005      33612           34.0
# 725     0.619442          3  0.021254      17127           17.0
# 282     0.517513         63  0.005172      20000           18.1
# 728     1.060267        105  0.006224      22759           19.9
# 1233    0.840951         26  0.006937      23527           20.1
# 1246    0.292624         16  0.008970      15104           12.6
# 1005    1.520720        -36  0.003709      90330           24.9
# 1022    1.090004         22  0.005331      33231           26.6
# 125     2.939923          3  0.003026     124291           24.8
# 1225    0.623355         21  0.010606      26729           21.2
# 1306    0.551025         38  0.011479      59433           23.0
# 1359    1.216662        102  0.004383      30856           22.8
# 88      1.646643          0  0.005537      53616           23.8
# 117     1.661084         16  0.005441      70097           25.0
#
#       popOver60perICU        date           county          state     fips  \
# 766             550.0  2020-06-17            Essex     New Jersey  34013.0
# 792            2385.0  2020-06-17         McKinley     New Mexico  35031.0
# 779            1328.0  2020-06-17            Union     New Jersey  34039.0
# 775            1013.0  2020-06-17          Passaic     New Jersey  34031.0
# 818             690.0  2020-06-17           Nassau       New York  36059.0
# 768            1047.0  2020-06-17           Hudson     New Jersey  34017.0
# 761            1440.0  2020-06-17           Bergen     New Jersey  34003.0
# 41             1834.0  2020-06-17       Tallapoosa        Alabama   1123.0
# 236             380.0  2020-06-17        Dougherty        Georgia  13095.0
# 269             225.0  2020-06-17            Upson        Georgia  13293.0
# 152            1008.0  2020-06-17           Morgan       Colorado   8087.0
# 836            1198.0  2020-06-17      Westchester       New York  36119.0
# 673             630.0  2020-06-17          Leflore    Mississippi  28083.0
# 624             619.0  2020-06-17            Wayne       Michigan  26163.0
# 159             932.0  2020-06-17         Hartford    Connecticut   9003.0
# 158            1141.0  2020-06-17        Fairfield    Connecticut   9001.0
# 774            1579.0  2020-06-17            Ocean     New Jersey  34029.0
# 770             818.0  2020-06-17           Mercer     New Jersey  34021.0
# 569             870.0  2020-06-17          Hampden  Massachusetts  25013.0
# 567            1770.0  2020-06-17            Essex  Massachusetts  25009.0
# 517             672.0  2020-06-17          Orleans      Louisiana  22071.0
# 831            1161.0  2020-06-17          Suffolk       New York  36103.0
# 777            2418.0  2020-06-17         Somerset     New Jersey  34035.0
# 780            1229.0  2020-06-17           Warren     New Jersey  34041.0
# 771             890.0  2020-06-17        Middlesex     New Jersey  34023.0
# 572            2630.0  2020-06-17          Norfolk  Massachusetts  25021.0
# 773            1215.0  2020-06-17           Morris     New Jersey  34027.0
# 4               736.0  2020-06-17           Butler        Alabama   1013.0
# 573            2551.0  2020-06-17         Plymouth  Massachusetts  25023.0
# 574             281.0  2020-06-17          Suffolk  Massachusetts  25025.0
# ...               ...         ...              ...            ...      ...
# 1385           1145.0  2020-06-17          Natrona        Wyoming  56025.0
# 11             1639.0  2020-06-17          Cullman        Alabama   1043.0
# 1248           2074.0  2020-06-17            Davis           Utah  49011.0
# 279             788.0  2020-06-17          Bannock          Idaho  16005.0
# 1004           2362.0  2020-06-17        Josephine         Oregon  41033.0
# 947             419.0  2020-06-17        Muskingum           Ohio  39119.0
# 689             258.0  2020-06-17            Boone       Missouri  29019.0
# 1143            289.0  2020-06-17            Maury      Tennessee  47119.0
# 476            1346.0  2020-06-17          Madison       Kentucky  21151.0
# 755             440.0  2020-06-17          Grafton  New Hampshire  33009.0
# 1223            595.0  2020-06-17           Nueces          Texas  48355.0
# 275            1475.0  2020-06-17         Honolulu         Hawaii  15003.0
# 1138            369.0  2020-06-17             Knox      Tennessee  47093.0
# 121            2601.0  2020-06-17       Santa Cruz     California   6087.0
# 835            2774.0  2020-06-17            Wayne       New York  36117.0
# 66              701.0  2020-06-17          Garland       Arkansas   5051.0
# 107            3361.0  2020-06-17           Nevada     California   6057.0
# 725            2141.0  2020-06-17         Gallatin        Montana  30031.0
# 282             571.0  2020-06-17       Bonneville          Idaho  16019.0
# 728             711.0  2020-06-17         Missoula        Montana  30063.0
# 1233            811.0  2020-06-17        Tom Green          Texas  48451.0
# 1246           1079.0  2020-06-17            Cache           Utah  49005.0
# 1005           1348.0  2020-06-17             Lane         Oregon  41039.0
# 1022            665.0  2020-06-17            Blair   Pennsylvania  42013.0
# 125            1516.0  2020-06-17           Sonoma     California   6097.0
# 1225           1336.0  2020-06-17           Parker          Texas  48367.0
# 1306           2972.0  2020-06-17           Kitsap     Washington  53035.0
# 1359            593.0  2020-06-17         Marathon      Wisconsin  55073.0
# 88             1247.0  2020-06-17            Butte     California   6007.0
# 117            1524.0  2020-06-17  San Luis Obispo     California   6079.0
#
#       cases  deaths  days_since_first_case  deaths_per_capita  \
# 766   18421    1755                     97           0.002193
# 792    2968     152                     89           0.002087
# 779   16315    1131                    100           0.002029
# 775   16683    1007                    101           0.001972
# 818   41320    2677                    104           0.001964
# 768   18755    1257                    100           0.001849
# 761   18928    1681                    105           0.001792
# 41      489      69                     86           0.001693
# 236    1845     151                     94           0.001650
# 269     308      42                     82           0.001601
# 152     646      45                     90           0.001600
# 836   34384    1539                    105           0.001578
# 673     385      47                     96           0.001561
# 624   21920    2678                     99           0.001518
# 159   11284    1331                     95           0.001483
# 158   16381    1352                    101           0.001427
# 774    9306     828                     96           0.001404
# 770    7393     523                     95           0.001401
# 569    6518     645                     94           0.001375
# 567   15703    1057                     99           0.001362
# 517    7459     523                     99           0.001347
# 831   40770    2006                    101           0.001339
# 777    4780     438                     93           0.001314
# 780    1206     140                     92           0.001307
# 771   16513    1094                     98           0.001307
# 572    8908     903                    107           0.001300
# 773    6627     640                     97           0.001283
# 4       554      25                     84           0.001242
# 573    8522     631                     94           0.001239
# 574   19434     959                    137           0.001228
# ...     ...     ...                    ...                ...
# 1385     88       1                     89           0.000012
# 11      290       1                     89           0.000012
# 1248    715       4                    103           0.000012
# 279      69       1                     85           0.000012
# 1004     26       1                     88           0.000012
# 947      60       1                     83           0.000012
# 689     222       2                     92           0.000011
# 1143    177       1                     89           0.000011
# 476      88       1                     88           0.000011
# 755      75       1                    107           0.000011
# 1223    420       4                     85           0.000011
# 275     508      11                    103           0.000011
# 1138    617       5                     97           0.000011
# 121     269       3                    102           0.000011
# 835     137       1                     90           0.000011
# 66      168       1                     94           0.000010
# 107      67       1                     93           0.000010
# 725     191       1                     96           0.000010
# 282      90       1                     81           0.000009
# 728      44       1                     95           0.000009
# 1233    131       1                     84           0.000009
# 1246   1087       1                     91           0.000008
# 1005     90       3                     92           0.000008
# 1022     55       1                     83           0.000008
# 125     803       4                    112           0.000008
# 1225    118       1                     85           0.000008
# 1306    180       2                    101           0.000008
# 1359     88       1                     89           0.000007
# 88       90       1                     88           0.000004
# 117     376       1                     95           0.000004
#
#       cases_per_capita  deaths_per_case
# 766           0.023015         0.095272
# 792           0.040742         0.051213
# 779           0.029274         0.069323
# 775           0.032676         0.060361
# 818           0.030314         0.064787
# 768           0.027591         0.067022
# 761           0.020181         0.088810
# 41            0.011998         0.141104
# 236           0.020159         0.081843
# 269           0.011737         0.136364
# 152           0.022971         0.069659
# 836           0.035254         0.044759
# 673           0.012785         0.122078
# 624           0.012428         0.122172
# 159           0.012574         0.117955
# 158           0.017292         0.082535
# 774           0.015781         0.088975
# 770           0.019801         0.070743
# 569           0.013892         0.098957
# 567           0.020239         0.067312
# 517           0.019215         0.070117
# 831           0.027224         0.049203
# 777           0.014341         0.091632
# 780           0.011262         0.116086
# 771           0.019722         0.066251
# 572           0.012829         0.101370
# 773           0.013285         0.096575
# 4             0.027527         0.045126
# 573           0.016739         0.074044
# 574           0.024894         0.049347
# ...                ...              ...
# 1385          0.001086         0.011364
# 11            0.003549         0.003448
# 1248          0.002134         0.005594
# 279           0.000820         0.014493
# 1004          0.000308         0.038462
# 947           0.000698         0.016667
# 689           0.001272         0.009009
# 1143          0.002020         0.005650
# 476           0.000996         0.011364
# 755           0.000840         0.013333
# 1223          0.001172         0.009524
# 275           0.000513         0.021654
# 1138          0.001364         0.008104
# 121           0.000984         0.011152
# 835           0.001498         0.007299
# 66            0.001714         0.005952
# 107           0.000678         0.014925
# 725           0.001896         0.005236
# 282           0.000815         0.011111
# 728           0.000385         0.022727
# 1233          0.001121         0.007634
# 1246          0.009037         0.000920
# 1005          0.000248         0.033333
# 1022          0.000441         0.018182
# 125           0.001603         0.004981
# 1225          0.000937         0.008475
# 1306          0.000695         0.011111
# 1359          0.000650         0.011364
# 88            0.000400         0.011111
# 117           0.001342         0.002660
#
# [1019 rows x 20 columns]
